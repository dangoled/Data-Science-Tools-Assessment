# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# <b>ANGOLE DANIEL</b><br>
# Network Infrasctructure Engineer

# %% [markdown]
# <i>I am intrested in data science because of the fact that it can uncover useful insights that may be hidden from the normal eye or other conventional data analysis tecniques.</i>

# %% [markdown]
# ### The following code tests the mathematical capabilities of Python by evaluating a simple arithmetic expression

# %%
2*((7+9)/4)-9
# Out:
# -1.0

# %% [markdown]
# <hr/>
#
# <b>Some of what I have learnt in this course</b>
#
# <ol>Week 1 <br><br>
#     <li> Languages of Data Science</li>
#         <ul>
#             <li>Python</li>
#             <li>R</li>
#             <li>SQL</li>
#             <li>Other Languages</li>
#         </ul><br><br>
#     <li> Data Science Tools</li>
#         <ul>
#             <li>Categories of Data Science Tools</li>
#             <li>Open source Tools</li>
#             <li>Commercial Tools</li>
#             <li>Cloud Based tools</li>
#         </ul><br><br>
#     <li> Packages, APIs, Data Sets and Models</li>
#         <ul>
#             <li>Libraries for Data Science</li>
#             <li>Application Programming Interfaces (API)</li>
#             <li>Data Asset eXchange</li>
#             <li>Machine Learning Models</li>
#         </ul><br><br>
# </ol>
#
# <ol>Week 2 <br><br>
#     <li> Jupyter Notebook and JupyterLab</li>
#         <ul>
#             <li>Getting started</li>
#             <li>Jupyter Kernels</li>
#             <li>Jupyter Architecture</li>
#         </ul><br><br>
#     <li> RStudio IDE</li>
#         <ul>
#             <li>Plotting with RStudio</li>
#             <li>Plotting with RStudio (Advanced)</li>
#         </ul><br><br>
#     <li> Github</li>
#         <ul>
#             <li>Overview</li>
#             <li>Wworking with Branches</li>
#             <li>Branching, Merging, and pull requests</li>
#             <li>Command line instructions</li>
#         </ul><br><br>
# </ol>
#
# Click here to read more <a href="https://www.coursera.org/learn/open-source-tools-for-data-science/home/week/2">Tools for Data Science</a>
